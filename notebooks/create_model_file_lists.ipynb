# %% [markdown]
# ### This notebook creates a list of files to download from each model for a given query of variables for the OMIP2 simulations.
# To do so, it uses the ESGF API. Will filter out models which have all of thegiven variables available. Will select one member per model. Will select the last OMIP cycle (last 61 years) for each simulation.

# %% [markdown]
# #### Install and import packages

# %%
pip install cmaps
# Out:
# Collecting cmaps
#   Using cached cmaps-1.0.5-py3-none-any.whl
# Requirement already satisfied: matplotlib in /srv/conda/envs/notebook/lib/python3.9/site-packages (from cmaps) (3.5.3)
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.9/site-packages (from cmaps) (1.23.2)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib->cmaps) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib->cmaps) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib->cmaps) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib->cmaps) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib->cmaps) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib->cmaps) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from matplotlib->cmaps) (4.36.0)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->cmaps) (1.16.0)
# Installing collected packages: cmaps
# Successfully installed cmaps-1.0.5
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xmip
# Out:
# Collecting xmip
#   Using cached xmip-0.6.1rc0-py3-none-any.whl (54 kB)
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xmip) (1.23.2)
# Requirement already satisfied: xarray>=0.17.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xmip) (2022.6.0)
# Collecting pint-xarray
#   Using cached pint_xarray-0.3-py3-none-any.whl (32 kB)
# Requirement already satisfied: cftime in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xmip) (1.6.1)
# Requirement already satisfied: cf-xarray>=0.6.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xmip) (0.7.4)
# Requirement already satisfied: pint in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xmip) (0.19.2)
# Requirement already satisfied: xarrayutils in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xmip) (1.1.1)
# Collecting xgcm<0.7.0
#   Using cached xgcm-0.6.1-py3-none-any.whl (60 kB)
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xmip) (1.4.3)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xarray>=0.17.0->xmip) (21.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pandas->xmip) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pandas->xmip) (2022.2.1)
# Requirement already satisfied: dask in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xgcm<0.7.0->xmip) (2022.8.0)
# Requirement already satisfied: future in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xgcm<0.7.0->xmip) (0.18.2)
# Requirement already satisfied: scipy in /srv/conda/envs/notebook/lib/python3.9/site-packages (from xarrayutils->xmip) (1.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from packaging>=20.0->xarray>=0.17.0->xmip) (3.0.9)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->xmip) (1.16.0)
# Requirement already satisfied: fsspec>=0.6.0 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from dask->xgcm<0.7.0->xmip) (2022.7.1)
# Requirement already satisfied: toolz>=0.8.2 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from dask->xgcm<0.7.0->xmip) (0.12.0)
# Requirement already satisfied: partd>=0.3.10 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from dask->xgcm<0.7.0->xmip) (1.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from dask->xgcm<0.7.0->xmip) (5.4.1)
# Requirement already satisfied: cloudpickle>=1.1.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from dask->xgcm<0.7.0->xmip) (2.1.0)
# Requirement already satisfied: locket in /srv/conda/envs/notebook/lib/python3.9/site-packages (from partd>=0.3.10->dask->xgcm<0.7.0->xmip) (1.0.0)
# Installing collected packages: xgcm, pint-xarray, xmip
#   Attempting uninstall: xgcm
#     Found existing installation: xgcm 0.8.0
#     Uninstalling xgcm-0.8.0:
#       Successfully uninstalled xgcm-0.8.0
# Successfully installed pint-xarray-0.3 xgcm-0.6.1 xmip-0.6.1rc0
# Note: you may need to restart the kernel to use updated packages.

# %%
from matplotlib import pyplot as plt
import xmip
import numpy as np
import pandas as pd
import xarray as xr
import cftime
import cmaps
import cartopy.crs as ccrs
import matplotlib.path as mpath

xr.set_options(display_style='html')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### Search function using ESGF API

# %%
#!/usr/bin/env python
from __future__ import print_function
import requests
import xml.etree.ElementTree as ET
import numpy

# Author: Unknown
# I got the original version from a word document published by ESGF
# https://docs.google.com/document/d/1pxz1Kd3JHfFp8vR2JCVBfApbsHmbUQQstifhGNdc6U0/edit?usp=sharing

# API AT: https://github.com/ESGF/esgf.github.io/wiki/ESGF_Search_REST_API#results-pagination

def esgf_search(server="https://esgf-node.llnl.gov/esg-search/search",
                files_type="OPENDAP", local_node=True, project="CMIP6",
                verbose=False, format="application%2Fsolr%2Bjson",
                use_csrf=False, **search):
    client = requests.session()
    payload = search
    payload["project"] = project
    payload["type"]= "File"
    if local_node:
        payload["distrib"] = "false"
    if use_csrf:
        client.get(server)
        if 'csrftoken' in client.cookies:
            # Django 1.6 and up
            csrftoken = client.cookies['csrftoken']
        else:
            # older versions
            csrftoken = client.cookies['csrf']
        payload["csrfmiddlewaretoken"] = csrftoken

    payload["format"] = format

    offset = 0
    numFound = 10000
    all_files = []
    files_type = files_type.upper()
    while offset < numFound:
        payload["offset"] = offset
        url_keys = [] 
        for k in payload:
            url_keys += ["{}={}".format(k, payload[k])]

        url = "{}/?{}".format(server, "&".join(url_keys))
        if offset % 100 == 0:
            print(url)
        r = client.get(url)
        r.raise_for_status()
        resp = r.json()["response"]
        numFound = int(resp["numFound"])
        resp = resp["docs"]
        offset += len(resp)
        for d in resp:
            if verbose:
                for k in d:
                    print("{}: {}".format(k,d[k]))
            url = d["url"]
            for f in d["url"]:
                sp = f.split("|")
                if sp[-1] == files_type:
                    all_files.append(sp[0].split(".html")[0])
    return sorted(all_files)

# %% [markdown]
# ### Perform the search to obtain a list of all available files for all possible models over all variables

# %%
variables = ['vmo','thetao','so','umo','siconc','zos','mlotst']
#variables = ['vmo']
fvariables = ['areacello','deptho']

result = []
for var in variables:
    result.append(esgf_search(activity_id='OMIP', variable_id=var,
                              experiment_id='omip2',frequency='mon',grid_label='gn'))
for var in fvariables:
    result.append(esgf_search(activity_id='OMIP',variable_id=var))
# Out:
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=vmo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=0
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=vmo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=100
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=vmo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=200
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=vmo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=300
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=vmo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=400
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=vmo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=500
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=vmo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=600
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=vmo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=700
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=vmo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=800
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=vmo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=900
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=vmo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=1000
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=vmo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=1100
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=vmo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=1200
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=thetao&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=0
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=thetao&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=100
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=thetao&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=200
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=thetao&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=300
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=thetao&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=400
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=thetao&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=500
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=thetao&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=600
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=thetao&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=700
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=thetao&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=800
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=thetao&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=900
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=thetao&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=1000
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=thetao&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=1100
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=thetao&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=1200
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=so&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=0
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=so&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=100
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=so&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=200
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=so&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=300
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=so&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=400
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=so&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=500
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=so&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=600
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=so&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=700
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=so&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=800
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=so&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=900
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=so&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=1000
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=so&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=1100
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=umo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=0
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=umo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=100
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=umo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=200
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=umo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=300
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=umo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=400
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=umo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=500
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=umo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=600
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=umo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=700
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=umo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=800
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=umo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=900
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=umo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=1000
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=umo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=1100
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=umo&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=1200
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=siconc&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=0
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=siconc&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=100
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=siconc&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=200
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=siconc&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=300
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=siconc&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=400
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=zos&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=0
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=zos&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=100
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=zos&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=200
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=zos&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=300
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=zos&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=400
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=zos&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=500
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=mlotst&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=0
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=mlotst&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=100
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=mlotst&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=200
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=mlotst&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=300
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=mlotst&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=400
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=mlotst&experiment_id=omip2&frequency=mon&grid_label=gn&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=500
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=areacello&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=0
# https://esgf-node.llnl.gov/esg-search/search/?activity_id=OMIP&variable_id=deptho&project=CMIP6&type=File&distrib=false&format=application%2Fsolr%2Bjson&offset=0

# %% [markdown]
# ### Filter models which have all variables available in one member, select the first member, select the last forcing cycle (last 61 years). Save file list for each model to a dictionary.

# %%
variables = ['vmo','thetao','so','umo','mlotst','zos']

all_variables = variables + fvariables

raw_results = [item for sublist in result for item in sublist] # concatenate lists from all variables
#print([r for r in raw_results if 'deptho' in r])
results = [r for r in raw_results if r.split('/')[-1].split('_')[0] in all_variables]
files = {} #final dictionary with each usable model as keys

models = set([r.split('_')[3] for r in results]) # models
print('All models that returned some search results:')
print(models)

print('---------------------------------------------------------------')
for model in models: # loop over model
    print()
    print(model)
    # get only the files from that model 
    tmp = [r for r in results if model in r] 
    # which variables does that model have?
    vvars = set([r.split('/')[-1].split('_')[0] for r in tmp])
    print('\tThe model has these variables available:')
    print('\t',vvars)
    
    if len(vvars) < len(all_variables):
        print('\t'+'Not enough variables - skipping model...')
        continue # throw out model if it doesn't have enough variables
        
    # selecting members
    members = list(sorted(set([r.split('_')[5] for r in tmp])))
    
    # make sure to sleect a member that has all the variables available
    good_members = []
    for member in members:
        tmp_member = [r for r in tmp if member in r]
        member_vars = set([r.split('/')[-1].split('_')[0] for r in tmp_member])
        if len(member_vars) == len(all_variables):
            good_members.append(member)
      
    if len(good_members) == 0:
        print('\t'+'No member has all the variables - skipping model...')
        print()
        continue
       
    # Create entry for that model
    files[model] = []
    
        
    print('\t'+'These members have all variables available:')
    print('\t',good_members)

    # select the first member that has all the variables available
    member = good_members[0]
    # cut data from that membe
    tmp_member = [r for r in tmp if member in r]
    
    # add grid variables
    for v in fvariables:
        # add just the first file from that file variable, as they should all be the same
        files[model].append([r for r in tmp_member if v in r][0])
        
    for v in variables: # loop over variables
        # cut out files from that variable
        tmp_var = [r for r in tmp_member if v+'_' in r]

        # select latest version and cut out files from that version
        version = list(sorted(set([r.split('/')[-2] for r in tmp_var])))[-1]
        tmp_version = [r for r in tmp_var if version in r]
        
        # figure out the year range in the files of that variables
        yy = [r.split('_')[-1].split('.')[0] for r in tmp_version]
        years = sorted(set(yy))
        
        # filter out double files from different nodes
        tmp_unique = []
        for y in years:
            tmp_unique.append([r for r in tmp_version if y in r][0])
            
        # figure out the last year, then select only files which contain 
        # data from the last 61 years (last OMIP forcing cycle)
        last_year = int(years[-1].split('-')[-1][0:4])
        print('\t'+v+':\tversion '+version+', Last cycle starts in '+str(last_year - 61+1))
        tmp_year = [tmp_var[i] for i in range(len(tmp_unique)) if int(yy[i].split('-')[-1][0:4]) > last_year - 61]  
        
        [files[model].append(r) for r in tmp_year]
        print('\tAdded '+str(len(tmp_year))+' file(s)')
        
print('These '+str(len(files.keys()))+' models match the requirements:')
print(sorted(files.keys()))
print('Saving file list for each models in model_files.npy')
np.save('models.npy',files)
# Out:
# All models that returned some search results:
# {'FGOALS-f3-H', 'GFDL-CM4', 'CNRM-CM6-1-HR', 'MIROC-ES2L', 'CanESM5-CanOE', 'CanESM5', 'MRI-ESM2-0', 'CMCC-CM2-SR5', 'ACCESS-OM2', 'TaiESM1-TIMCOM2', 'MIROC6', 'CNRM-ESM2-1', 'ACCESS-OM2-025', 'CMCC-CM2-HR4', 'CESM2', 'IPSL-CM6A-LR', 'NorESM2-LM', 'EC-Earth3', 'CMCC-ESM2', 'GFDL-OM4p5B', 'CNRM-CM6-1', 'FGOALS-f3-L', 'TaiESM1-TIMCOM'}
# ---------------------------------------------------------------
#
# FGOALS-f3-H
# 	The model has these variables available:
# 	 {'areacello', 'deptho'}
# 	Not enough variables - skipping model...
#
# GFDL-CM4
# 	The model has these variables available:
# 	 {'areacello', 'deptho'}
# 	Not enough variables - skipping model...
#
# CNRM-CM6-1-HR
# 	The model has these variables available:
# 	 {'areacello', 'thetao', 'deptho', 'mlotst', 'umo', 'so', 'zos', 'vmo'}
# 	These members have all variables available:
# 	 ['r1i1p1f2']
# 	vmo:	version v20210412, Last cycle starts in 1958
# 	Added 30 file(s)
# 	thetao:	version v20210412, Last cycle starts in 1958
# 	Added 30 file(s)
# 	so:	version v20210412, Last cycle starts in 1958
# 	Added 13 file(s)
# 	umo:	version v20210412, Last cycle starts in 1958
# 	Added 30 file(s)
# 	mlotst:	version v20210412, Last cycle starts in 1958
# 	Added 1 file(s)
# 	zos:	version v20210412, Last cycle starts in 1958
# 	Added 1 file(s)
#
# MIROC-ES2L
# 	The model has these variables available:
# 	 {'areacello', 'deptho'}
# 	Not enough variables - skipping model...
#
# CanESM5-CanOE
# 	The model has these variables available:
# 	 {'areacello', 'deptho'}
# 	Not enough variables - skipping model...
#
# CanESM5
# 	The model has these variables available:
# 	 {'areacello', 'deptho'}
# 	Not enough variables - skipping model...
#
# MRI-ESM2-0
# 	The model has these variables available:
# 	 {'areacello', 'thetao', 'deptho', 'mlotst', 'umo', 'so', 'zos', 'vmo'}
# 	These members have all variables available:
# 	 ['r1i1p1f1', 'r1i1p2f1', 'r1i1p3f1', 'r1i1p4f1', 'r2i1p1f1']
# 	vmo:	version v20200406, Last cycle starts in 1958
# 	Added 1 file(s)
# 	thetao:	version v20210510, Last cycle starts in 1958
# 	Added 1 file(s)
# 	so:	version v20210510, Last cycle starts in 1958
# 	Added 1 file(s)
# 	umo:	version v20200406, Last cycle starts in 1958
# 	Added 1 file(s)
# 	mlotst:	version v20210510, Last cycle starts in 1958
# 	Added 1 file(s)
# 	zos:	version v20210510, Last cycle starts in 1958
# 	Added 1 file(s)
#
# CMCC-CM2-SR5
# 	The model has these variables available:
# 	 {'areacello', 'thetao', 'deptho', 'mlotst', 'umo', 'so', 'zos', 'vmo'}
# 	These members have all variables available:
# 	 ['r1i1p1f1']
# 	vmo:	version v20200226, Last cycle starts in 1958
# 	Added 1 file(s)
# 	thetao:	version v20200226, Last cycle starts in 1958
# 	Added 1 file(s)
# 	so:	version v20200226, Last cycle starts in 1958
# 	Added 1 file(s)
# 	umo:	version v20200226, Last cycle starts in 1958
# 	Added 1 file(s)
# 	mlotst:	version v20200226, Last cycle starts in 1958
# 	Added 1 file(s)
# 	zos:	version v20200226, Last cycle starts in 1958
# 	Added 1 file(s)
#
# ACCESS-OM2
# 	The model has these variables available:
# 	 {'areacello', 'thetao', 'deptho', 'mlotst', 'umo', 'so', 'zos', 'vmo'}
# 	These members have all variables available:
# 	 ['r1i1p1f1']
# 	vmo:	version v20210617, Last cycle starts in 306
# 	Added 61 file(s)
# 	thetao:	version v20210617, Last cycle starts in 306
# 	Added 61 file(s)
# 	so:	version v20210617, Last cycle starts in 306
# 	Added 61 file(s)
# 	umo:	version v20210617, Last cycle starts in 306
# 	Added 61 file(s)
# 	mlotst:	version v20210617, Last cycle starts in 306
# 	Added 7 file(s)
# 	zos:	version v20210617, Last cycle starts in 306
# 	Added 7 file(s)
#
# TaiESM1-TIMCOM2
# 	The model has these variables available:
# 	 {'areacello', 'thetao', 'deptho', 'mlotst', 'umo', 'so', 'zos', 'vmo'}
# 	These members have all variables available:
# 	 ['r1i1p1f1']
# 	vmo:	version v20211216, Last cycle starts in 306
# 	Added 1 file(s)
# 	thetao:	version v20211216, Last cycle starts in 306
# 	Added 1 file(s)
# 	so:	version v20211216, Last cycle starts in 306
# 	Added 1 file(s)
# 	umo:	version v20211216, Last cycle starts in 306
# 	Added 1 file(s)
# 	mlotst:	version v20211216, Last cycle starts in 306
# 	Added 1 file(s)
# 	zos:	version v20211216, Last cycle starts in 306
# 	Added 1 file(s)
#
# MIROC6
# 	The model has these variables available:
# 	 {'areacello', 'thetao', 'deptho', 'mlotst', 'umo', 'so', 'zos', 'vmo'}
# 	These members have all variables available:
# 	 ['r2i1p1f1']
# 	vmo:	version v20210129, Last cycle starts in 1949
# 	Added 7 file(s)
# 	thetao:	version v20200612, Last cycle starts in 1949
# 	Added 7 file(s)
# 	so:	version v20200612, Last cycle starts in 1949
# 	Added 7 file(s)
# 	umo:	version v20210129, Last cycle starts in 1949
# 	Added 7 file(s)
# 	mlotst:	version v20210129, Last cycle starts in 1949
# 	Added 2 file(s)
# 	zos:	version v20200612, Last cycle starts in 1949
# 	Added 2 file(s)
#
# CNRM-ESM2-1
# 	The model has these variables available:
# 	 {'areacello', 'deptho'}
# 	Not enough variables - skipping model...
#
# ACCESS-OM2-025
# 	The model has these variables available:
# 	 {'areacello', 'thetao', 'deptho', 'mlotst', 'umo', 'so', 'zos', 'vmo'}
# 	These members have all variables available:
# 	 ['r1i1p1f1']
# 	vmo:	version v20210617, Last cycle starts in 306
# 	Added 61 file(s)
# 	thetao:	version v20210617, Last cycle starts in 306
# 	Added 61 file(s)
# 	so:	version v20210617, Last cycle starts in 306
# 	Added 61 file(s)
# 	umo:	version v20210617, Last cycle starts in 306
# 	Added 61 file(s)
# 	mlotst:	version v20210617, Last cycle starts in 306
# 	Added 7 file(s)
# 	zos:	version v20210617, Last cycle starts in 306
# 	Added 7 file(s)
#
# CMCC-CM2-HR4
# 	The model has these variables available:
# 	 {'areacello', 'thetao', 'deptho', 'mlotst', 'umo', 'so', 'zos', 'vmo'}
# 	These members have all variables available:
# 	 ['r1i1p1f1']
# 	vmo:	version v20200226, Last cycle starts in 1958
# 	Added 6 file(s)
# 	thetao:	version v20200226, Last cycle starts in 1958
# 	Added 6 file(s)
# 	so:	version v20200226, Last cycle starts in 1958
# 	Added 6 file(s)
# 	umo:	version v20200226, Last cycle starts in 1958
# 	Added 6 file(s)
# 	mlotst:	version v20200226, Last cycle starts in 1958
# 	Added 1 file(s)
# 	zos:	version v20200226, Last cycle starts in 1958
# 	Added 1 file(s)
#
# CESM2
# 	The model has these variables available:
# 	 {'areacello', 'thetao', 'deptho', 'mlotst', 'so', 'zos'}
# 	Not enough variables - skipping model...
#
# IPSL-CM6A-LR
# 	The model has these variables available:
# 	 {'areacello'}
# 	Not enough variables - skipping model...
#
# NorESM2-LM
# 	The model has these variables available:
# 	 {'areacello', 'thetao', 'deptho', 'mlotst', 'umo', 'so', 'zos', 'vmo'}
# 	These members have all variables available:
# 	 ['r1i1p1f1']
# 	vmo:	version v20190920, Last cycle starts in 1958
# 	Added 7 file(s)
# 	thetao:	version v20190920, Last cycle starts in 1958
# 	Added 7 file(s)
# 	so:	version v20190920, Last cycle starts in 1958
# 	Added 7 file(s)
# 	umo:	version v20190920, Last cycle starts in 1958
# 	Added 7 file(s)
# 	mlotst:	version v20190920, Last cycle starts in 1958
# 	Added 7 file(s)
# 	zos:	version v20190920, Last cycle starts in 1958
# 	Added 7 file(s)
#
# EC-Earth3
# 	The model has these variables available:
# 	 {'areacello', 'thetao', 'deptho', 'mlotst', 'umo', 'so', 'zos', 'vmo'}
# 	These members have all variables available:
# 	 ['r1i1p1f1']
# 	vmo:	version v20200928, Last cycle starts in 1958
# 	Added 61 file(s)
# 	thetao:	version v20200928, Last cycle starts in 1958
# 	Added 61 file(s)
# 	so:	version v20200928, Last cycle starts in 1958
# 	Added 61 file(s)
# 	umo:	version v20200928, Last cycle starts in 1958
# 	Added 61 file(s)
# 	mlotst:	version v20200928, Last cycle starts in 1958
# 	Added 61 file(s)
# 	zos:	version v20200928, Last cycle starts in 1958
# 	Added 61 file(s)
#
# CMCC-ESM2
# 	The model has these variables available:
# 	 {'areacello', 'deptho'}
# 	Not enough variables - skipping model...
#
# GFDL-OM4p5B
# 	The model has these variables available:
# 	 {'areacello'}
# 	Not enough variables - skipping model...
#
# CNRM-CM6-1
# 	The model has these variables available:
# 	 {'areacello', 'thetao', 'deptho', 'mlotst', 'umo', 'so', 'zos', 'vmo'}
# 	These members have all variables available:
# 	 ['r1i1p1f2']
# 	vmo:	version v20210412, Last cycle starts in 1958
# 	Added 30 file(s)
# 	thetao:	version v20210412, Last cycle starts in 1958
# 	Added 30 file(s)
# 	so:	version v20210412, Last cycle starts in 1958
# 	Added 13 file(s)
# 	umo:	version v20210412, Last cycle starts in 1958
# 	Added 30 file(s)
# 	mlotst:	version v20210412, Last cycle starts in 1958
# 	Added 1 file(s)
# 	zos:	version v20210412, Last cycle starts in 1958
# 	Added 1 file(s)
#
# FGOALS-f3-L
# 	The model has these variables available:
# 	 {'areacello', 'thetao', 'deptho', 'mlotst', 'umo', 'so', 'zos', 'vmo'}
# 	These members have all variables available:
# 	 ['r1i1p1f1']
# 	vmo:	version v20191217, Last cycle starts in 1958
# 	Added 1 file(s)
# 	thetao:	version v20191104, Last cycle starts in 1958
# 	Added 1 file(s)
# 	so:	version v20191104, Last cycle starts in 1958
# 	Added 1 file(s)
# 	umo:	version v20191119, Last cycle starts in 1958
# 	Added 1 file(s)
# 	mlotst:	version v20191104, Last cycle starts in 1958
# 	Added 1 file(s)
# 	zos:	version v20191104, Last cycle starts in 1958
# 	Added 1 file(s)
#
# TaiESM1-TIMCOM
# 	The model has these variables available:
# 	 {'areacello', 'thetao', 'deptho', 'mlotst', 'umo', 'so', 'zos', 'vmo'}
# 	These members have all variables available:
# 	 ['r1i1p1f1']
# 	vmo:	version v20211216, Last cycle starts in 306
# 	Added 1 file(s)
# 	thetao:	version v20211216, Last cycle starts in 306
# 	Added 1 file(s)
# 	so:	version v20211216, Last cycle starts in 306
# 	Added 1 file(s)
# 	umo:	version v20211216, Last cycle starts in 306
# 	Added 1 file(s)
# 	mlotst:	version v20211216, Last cycle starts in 306
# 	Added 1 file(s)
# 	zos:	version v20211216, Last cycle starts in 306
# 	Added 1 file(s)
# These 13 models match the requirements:
# ['ACCESS-OM2', 'ACCESS-OM2-025', 'CMCC-CM2-HR4', 'CMCC-CM2-SR5', 'CNRM-CM6-1', 'CNRM-CM6-1-HR', 'EC-Earth3', 'FGOALS-f3-L', 'MIROC6', 'MRI-ESM2-0', 'NorESM2-LM', 'TaiESM1-TIMCOM', 'TaiESM1-TIMCOM2']
# Saving file list for each models in model_files.npy

# %%
files['CNRM-CM6-1']
# Out:
# ['http://aims3.llnl.gov/thredds/dodsC/css03_data/CMIP6/OMIP/CNRM-CERFACS/CNRM-CM6-